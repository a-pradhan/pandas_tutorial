# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
from numpy.random import randn

# Stats
from scipy import stats

# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = randn(100)

# %%
# make combined plot, by default a kernel density estimation plot and a histogram 
sns.distplot(dataset,bins=25)

# %%
sns.distplot(dataset,bins=25,rug=True,hist=False)

# %%
# set specific colours, parameters by passing dictionaries as arguments to distplot
sns.distplot(dataset,bins=25,
             kde_kws={'color':'indianred','label':'KDE PLOT'},
             hist_kws={'color':'blue','label':'HIST'})

# %%
ser1 = Series(dataset,name="My_data")
ser1
# Out:
# 0    -0.603182
# 1     1.274176
# 2    -0.533968
# 3     0.021020
# 4     1.835776
# 5     0.290838
# 6     0.077274
# 7    -1.527998
# 8    -0.289951
# 9     0.637851
# 10   -1.871943
# 11   -0.927403
# 12    0.685998
# 13   -2.572850
# 14    2.629385
# 15    1.239766
# 16   -0.694959
# 17   -2.594400
# 18    0.572904
# 19    0.373849
# 20    0.084272
# 21    1.044753
# 22    0.436922
# 23    0.059094
# 24   -0.701549
# 25   -0.078524
# 26   -0.690967
# 27   -0.775630
# 28   -0.080773
# 29    0.773335
#         ...
# 70   -1.016823
# 71   -1.008373
# 72    0.272116
# 73    0.872780
# 74    0.472863
# 75   -0.987530
# 76   -0.743567
# 77    2.066460
# 78    2.169253
# 79   -1.307302
# 80   -0.972325
# 81    0.208850
# 82    1.119912
# 83    0.189557
# 84    0.223528
# 85    0.464107
# 86   -0.718775
# 87   -0.425853
# 88    0.750110
# 89   -2.537063
# 90    0.746640
# 91   -0.325661
# 92   -2.475875
# 93   -0.367332
# 94    0.814041
# 95   -0.168395
# 96   -1.106439
# 97    2.194286
# 98   -1.017934
# 99   -0.241418
# Name: My_data, dtype: float64

# %%
sns.distplot(ser1,bins =25)
