# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
'''

'''
# Out:
# '\n\n'

# %%
dframe_wine = pd.read_csv('winequality-red.csv',sep=';')
dframe_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# what if we want to know the highest alcohol content wine for each quality range. We can find out using split,
# apply, combine procedure
# create function that assigns a rank for alcohol content. 1 is the highest rank
def ranker(df):
    df['alc_content_rank'] = np.arange(len(df)) + 1
    return df

# %%
# sort df by alcohol in ascending order
dframe_wine.sort_values(by='alcohol', ascending=False, inplace=True)
dframe_wine.head()
dframe_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1599 entries, 652 to 517
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 162.4 KB

# %%
dframe_grp = dframe_wine.groupby('quality')
dframe_grp.mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 652            15.9             0.360         0.65            7.50      0.096
# 588             5.0             0.420         0.24            2.00      0.060
# 142             5.2             0.340         0.00            1.80      0.050
# 144             5.2             0.340         0.00            1.80      0.050
# 1270            5.0             0.380         0.01            1.60      0.048
# 1269            5.5             0.490         0.03            1.80      0.044
# 467             8.8             0.460         0.45            2.60      0.065
# 821             4.9             0.420         0.00            2.10      0.048
# 1114            5.0             0.400         0.50            4.30      0.046
# 1228            5.1             0.420         0.00            1.80      0.044
# 1132            7.4             0.360         0.34            1.80      0.075
# ...

# %%
# now find highest alc content for each ranking
num_of_qual = dframe_wine['quality'].value_counts()
num_of_qual
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
dframe_wine[dframe_wine.alc_content_rank == 1].head(len(num_of_qual))
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 652           15.9              0.36         0.65             7.5      0.096
# 588            5.0              0.42         0.24             2.0      0.060
# 142            5.2              0.34         0.00             1.8      0.050
# 821            4.9              0.42         0.00             2.1      0.048
# 45             4.6              0.52         0.15             2.1      0.054
# 899            8.3              1.02         0.02             3.4      0.084
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 652                 22.0                  71.0  0.99760  2.98       0.84
# 588                 19.0                  50.0  0.99170  3.72       0.74
# 142                 27.0                  63.0  0.99160  3.68       0.79
# 821                 16.0                  42.0  0.99154  3.71       0.74
# ...
